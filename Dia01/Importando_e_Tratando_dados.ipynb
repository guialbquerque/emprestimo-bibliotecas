# %% [markdown]
# ### Dia 01 - Importando os dados de emprestimos da biblioteca dos ultimos 10 anos.
#
# - #### Importar os dados
# - #### Juntar os dados
# - #### Limpar os dados

# %%
import pandas as pd

# %%
df1 = pd.read_csv('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/dados_emprestimos/emprestimos-20101.csv')
df2 = pd.read_csv('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/dados_emprestimos/emprestimos-20102.csv')
df3 = pd.read_csv('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/dados_emprestimos/emprestimos-20111.csv')
df4 = pd.read_csv('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/dados_emprestimos/emprestimos-20112.csv')
df5 = pd.read_csv('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/dados_emprestimos/emprestimos-20121.csv')
df6 = pd.read_csv('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/dados_emprestimos/emprestimos-20122.csv')
df7 = pd.read_csv('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/dados_emprestimos/emprestimos-20131.csv')
df8 = pd.read_csv('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/dados_emprestimos/emprestimos-20132.csv')
df9 = pd.read_csv('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/dados_emprestimos/emprestimos-20141.csv')
df10 = pd.read_csv('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/dados_emprestimos/emprestimos-20142.csv')
df11 = pd.read_csv('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/dados_emprestimos/emprestimos-20151.csv')
df12 = pd.read_csv('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/dados_emprestimos/emprestimos-20152.csv')
df13 = pd.read_csv('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/dados_emprestimos/emprestimos-20161.csv')
df14 = pd.read_csv('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/dados_emprestimos/emprestimos-20162.csv')
df15 = pd.read_csv('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/dados_emprestimos/emprestimos-20171.csv')
df16 = pd.read_csv('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/dados_emprestimos/emprestimos-20172.csv')
df17 = pd.read_csv('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/dados_emprestimos/emprestimos-20181.csv')
df18 = pd.read_csv('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/dados_emprestimos/emprestimos-20182.csv')
df19 = pd.read_csv('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/dados_emprestimos/emprestimos-20191.csv')
df20 = pd.read_csv('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/dados_emprestimos/emprestimos-20192.csv')
df21 = pd.read_csv('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/dados_emprestimos/emprestimos-20201.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95357 entries, 0 to 95356
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id_emprestimo         95357 non-null  int64
#  1   codigo_barras         95357 non-null  object
#  2   data_renovacao        38803 non-null  object
#  3   data_emprestimo       95357 non-null  object
#  4   data_devolucao        95354 non-null  object
#  5   matricula_ou_siape    95155 non-null  float64
#  6   tipo_vinculo_usuario  95357 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 5.1+ MB

# %%
df21.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0        2962509    2007005628                            NaN
# 1        2962510       L202802                            NaN
# 2        2962511    2012008328                            NaN
# 3        2962512    2012055016  2020/01/17 09:56:18.380000000
# 4        2962513       L197391  2020/01/17 23:50:18.862000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2020/01/02 08:17:30.290000000  2020/01/07 11:14:07.000000000
# 1  2020/01/02 08:17:30.391000000  2020/01/07 11:14:17.000000000
# 2  2020/01/02 08:17:30.436000000  2020/01/07 11:24:46.000000000
# 3  2020/01/02 08:36:40.163000000  2020/01/31 14:53:52.000000000
# 4  2020/01/02 09:36:03.877000000  2020/01/24 08:18:19.000000000
#
#    matricula_ou_siape    tipo_vinculo_usuario
# 0        2.018103e+10  ALUNO DE PÓS-GRADUAÇÃO
# 1        2.018103e+10  ALUNO DE PÓS-GRADUAÇÃO
# 2        2.018103e+10  ALUNO DE PÓS-GRADUAÇÃO
# ...

# %% [markdown]
# ### Concatenando em um unico DataFrame

# %%
df_final = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21]
                     , ignore_index=True)

# %%
df_final.head(10)
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709684       L095049                            NaN
# 5         709685       L167050                            NaN
# 6         709686    2006017618  2010/01/26 08:07:01.738000000
# 7         709687       L184117  2010/01/18 11:07:46.470000000
# 8         709688    2007027500  2010/01/19 15:59:26.464000000
# 9         709689       L157395  2010/01/19 15:59:26.447000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# ...

# %% [markdown]
# ### Verificando dados nulos

# %%
df_final.isna().sum()
# Out:
# id_emprestimo                 0
# codigo_barras                 0
# data_renovacao          1285720
# data_emprestimo               0
# data_devolucao             6471
# matricula_ou_siape         3170
# tipo_vinculo_usuario          0
# dtype: int64

# %% [markdown]
# ### Realizando limpeza dos dados

# %%
df_cleaned = df_final.dropna(subset=['data_renovacao', 'data_devolucao', 'matricula_ou_siape'])
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 968054 entries, 2 to 2257991
# Data columns (total 7 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id_emprestimo         968054 non-null  int64
#  1   codigo_barras         968054 non-null  object
#  2   data_renovacao        968054 non-null  object
#  3   data_emprestimo       968054 non-null  object
#  4   data_devolucao        968054 non-null  object
#  5   matricula_ou_siape    968054 non-null  float64
#  6   tipo_vinculo_usuario  968054 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 59.1+ MB

# %%
new_index = range(df_cleaned.shape[0])

# %%
df_cleaned.index = new_index

# %%
df_cleaned.to_csv('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/df_final.csv', index = False)

# %%
df_cleaned.drop_duplicates(inplace = True)
# Out:
# /tmp/ipykernel_2081/4228461740.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned.drop_duplicates(inplace = True)

# %%
df_cleaned.sort_values(by = 'codigo_barras')
# Out:
#         id_emprestimo codigo_barras                 data_renovacao  \
# 369801        1550079        000029  2013/08/13 11:05:34.593000000
# 171930        1112628        000029  2011/11/07 19:44:44.158000000
# 61336          843953        000029  2010/10/10 09:42:03.994000000
# 516938        1902302        000029  2015/02/19 20:00:43.113000000
# 552517        1979166        000029  2015/05/07 21:11:58.943000000
# ...               ...           ...                            ...
# 673428        2282402       Z097066  2016/09/12 06:23:22.672000000
# 150932        1069649       Z097066  2011/09/21 08:44:04.824000000
# 15138          740629       Z097066  2010/04/20 08:46:42.916000000
# 695438        2333271       Z097066  2016/11/22 08:31:11.856000000
# 105482         968940       Z097066  2011/05/11 06:34:42.584000000
#
#                       data_emprestimo                 data_devolucao  \
# 369801  2013/07/31 07:56:38.195000000  2013/08/27 07:49:08.000000000
# ...

# %%
pq = pd.read_parquet('/home/gondor/DevEnvironment/Python/AluraCursos/SevenDaysOfCode/ProjetoEmprestimoBiblioteca/Datasets/dados_acervo/dados_exemplares.parquet',
                     engine='pyarrow')
pq.head()
# Out:
#        id_exemplar codigo_barras            colecao  \
# index
# 0                5       L000003  Acervo Circulante
# 1                4       L000002  Acervo Circulante
# 2                3       L000001  Acervo Circulante
# 3                7       L000114  Acervo Circulante
# 5               10       L000041  Acervo Circulante
#
#                            biblioteca status_material  localizacao  \
# index
# 0      Biblioteca Central Zila Mamede         REGULAR          694
# 1      Biblioteca Central Zila Mamede         REGULAR          688
# 2      Biblioteca Central Zila Mamede        ESPECIAL          638
# 3      Biblioteca Central Zila Mamede         REGULAR          616
# 5      Biblioteca Central Zila Mamede        ESPECIAL          657
#
#        registro_sistema
# index
# 0                     1
# 1                     1
# 2                     1
# 3                     5
# 5                    15

# %%
pq.drop([43465, 160363], axis=0, inplace=True)

# %%
pq.sort_values(by = 'codigo_barras')
# Out:
#         id_exemplar codigo_barras              colecao  \
# index
# 270326       266970        000001  Obras de Referência
# 270327       266971        000002  Obras de Referência
# 270328       266972        000003  Obras de Referência
# 270329       266973        000004  Obras de Referência
# 270330       266974        000005  Obras de Referência
# ...             ...           ...                  ...
# 75271         82201       Z095251    Acervo Circulante
# 92078        101698       Z096429    Acervo Circulante
# 145083        13030       Z097066    Acervo Circulante
# 221077       226458       Z099627    Acervo Circulante
# 223330       228383       Z099945    Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 270326  Biblioteca Setorial Bertha Cruz Enders - ­Esco...     NÃO CIRCULA
# 270327  Biblioteca Setorial Bertha Cruz Enders - ­Esco...     NÃO CIRCULA
# ...

# %%
df_merge = pd.merge(df_cleaned, pq, on = 'codigo_barras', how = 'inner')

# %%
df_merge['colecao'].value_counts()
# Out:
# colecao
# Acervo Circulante                        905008
# Monografias                                 560
# Publicações de Autores do RN                328
# Publicações da UFRN                         223
# Multimeios                                   72
# Obras de Referência                          60
# Dissertações                                 50
# Folhetos                                     35
# Coleção Mossoroense                          19
# Eventos                                      16
# Coleção Zila Mamede                          14
# Necessidades Educacionais Específicas        14
# Literatura de Cordel                          6
# Teses                                         3
# Trabalho Acadêmico                            2
# Obras Raras                                   2
# Name: count, dtype: int64

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 906412 entries, 0 to 906411
# Data columns (total 13 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id_emprestimo         906412 non-null  int64
#  1   codigo_barras         906412 non-null  object
#  2   data_renovacao        906412 non-null  object
#  3   data_emprestimo       906412 non-null  object
#  4   data_devolucao        906412 non-null  object
#  5   matricula_ou_siape    906412 non-null  float64
#  6   tipo_vinculo_usuario  906412 non-null  object
#  7   id_exemplar           906412 non-null  int64
#  8   colecao               906412 non-null  object
#  9   biblioteca            906412 non-null  object
#  10  status_material       906412 non-null  object
#  11  localizacao           906412 non-null  int64
#  12  registro_sistema      906412 non-null  int64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 89.9+ MB
